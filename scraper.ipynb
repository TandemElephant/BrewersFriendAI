# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup
import re

from tqdm import tqdm_notebook as tqdm

# %%
pd.set_option('display.max_columns', 500)

# %%
url_home = 'https://www.brewersfriend.com'

page_num = 1
r = requests.get(url_home + '/homebrew-recipes/page/' + str(page_num) + '/?sort=breweddown', headers={'User-Agent': 'Mozilla/5.0'})
soup = BeautifulSoup(r.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html ng-app="bfApp">
#  <head>
#   <script crossorigin="anonymous" src="https://browser.sentry-cdn.com/4.6.4/bundle.min.js">
#   </script>
#   <script type="text/javascript">
#    Sentry.init({
# 	dsn: 'https://1bf3f44ed68e4195ad7c6c3209f82a6a@sentry.io/1176007',
# 	environment: "www.brewersfriend.com",
# 	release: "9517c21e46f20f07a55a7a1d8d1adcc4564d987f",
# 	blacklistUrls: [
#         // Ignore file:// URLs when people save pages they shouldn't
#         /file:\/\//
# 	],
# 	whitelistUrls: [
#         'www.brewersfriend.com',
#         'beta.brewersfriend.com',
#         'josh.brewersfriend.com'
#     ]
# });
#
# Sentry.configureScope(function(scope) {
# 	scope.setUser({"ip_address":"94.21.233.128"});
# });
#   </script>
#   <script>
#    dataLayer = (typeof dataLayer === 'undefined') ? [] : dataLayer;
#
# dataLayer.push({'bf_email': ""});
#
# dataLayer.push({'bf_homepage_photo': ""});
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KJGMPS');
#   </script>
#   <!-- BEGIN ADS -->
#   <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   </script>
#   <script>
#    googletag.cmd.push(function() {
# 			googletag.defineSlot('/21749616217/bf_top_banner_728x90', [728, 90], "div-gpt-ad-1546203137769-0").addService(googletag.pubads());
# 			googletag.defineSlot('/21749616217/bf_bottom_banner_728x90', [728, 90], "div-gpt-ad-1546220596731-0").addService(googletag.pubads());
# 			googletag.defineSlot('/21749616217/bf_top_300x100', [300, 100], "div-gpt-ad-1546221040288-0").addService(googletag.pubads());
# 			googletag.defineSlot('/21749616217/bf_bottom_300x250', [300, 250], "div-gpt-ad-1546221088860-0").addService(googletag.pubads());
# 	    googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#   </script>
#   <script type="text/javascript">
#    window.render_bf_blog_ad = function(ad_id) {
#
# 	var original_ad_id = ad_id;
#
#     if (!window.bf_d_a)
# 	{
# 		bf_ad_slots = {"top_728x90":["div-gpt-ad-1546203137769-0",728,90,"\/21749616217\/bf_top_banner_728x90"],"bottom_728x90":["div-gpt-ad-1546220596731-0",728,90,"\/21749616217\/bf_bottom_banner_728x90"],"top_300x250":["div-gpt-ad-1546221040288-0",300,100,"\/21749616217\/bf_top_300x100"],"bottom_300x250":["div-gpt-ad-1546221088860-0",300,250,"\/21749616217\/bf_bottom_300x250"]};
#
#         switch(ad_id) {
#         case 'div-gpt-ad-1453778999114-0':
# 			ad_id = "div-gpt-ad-1546221088860-0";
#             break;
#         case 'div-gpt-ad-1453778999114-1':
# 			ad_id = "div-gpt-ad-1546221040288-0";
#             break;
#         case 'div-gpt-ad-1453778999114-2':
# 			ad_id = 'div-gpt-ad-1546203137769-0';
#             break;
#         case 'div-gpt-ad-1453778999114-3':
# 			ad_id = 'div-gpt-ad-1546220596731-0';
#             break;
# 		}
#
#
# 		if ( !bf_ad_slots[ad_id] ) {
# 			jQuery.each(bf_ad_slots, function (index, value) {
#
# 				if ( value[0] == ad_id ) {
# 					ad_id = index;
# 				}
#
# 			});
# 		}
#
#
# 		if (bf_ad_slots[ad_id]) {
# 			ad_slot_data = bf_ad_slots[ad_id];
#
# 			jQuery('#' + original_ad_id).attr('id', original_ad_id + '_cont');
#
# 			jQuery('#' + original_ad_id + '_cont').html(
# 				'<!-- ' + ad_slot_data[3] + ' -->'
# 				+
# 				'<div id="' + ad_slot_data[0] + '" style="width:' + ad_slot_data[1] + 'px; height:' + (20 + ad_slot_data[2]) + 'px;margin:0 auto;">' +
# 				'</div>'
# 			);
#
# 		    jQuery('#' + original_ad_id + '_cont').prepend(
# 				'<div class="ad-message" style="height: 20px; font-size: 13px; text-decoration: underline; text-align: center;">' +
# 				'<a href="/homebrew/signup">' +
# 				(ad_slot_data[1] > 600 ?
# 				'Want no ads? Go Premium and unlock all our brewing tools!' :
# 				'Want no ads? Go Premium!') +
# 				'<' + '/a>' +
# 				'<' + '/div>'
# 			);
#
# 			googletag.cmd.push(function() { googletag.display(ad_slot_data[0]); });
# 		}
#     }
#     else
#     {
#         $(document).ready(function(){
#             $('#' + ad_id).hide();
#         });
#     }
# };
#   </script>
#   <!-- END ADS -->
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#    <title>
#     Homebrew Beer Recipes | Brewer's Friend
#    </title>
#    <meta content="home brew recipes,brewing beer,beer recipes,beer recipe list" name="keywords"/>
#    <link href="https://www.brewersfriend.com/homebrew/images/favicon.ico" rel="shortcut icon"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/dropzone/5.5.1/dropzone.css" rel="stylesheet"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/transition.min.css" rel="stylesheet"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/dropdown.min.css" rel="stylesheet"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/button.min.css" rel="stylesheet"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/card.min.css" rel="stylesheet"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/dimmer.min.css" rel="stylesheet"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/modal.min.css" rel="stylesheet"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/search.min.css" rel="stylesheet"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/label.min.css" rel="stylesheet"/>
#    <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/message.min.css" rel="stylesheet"/>
#    <link href="https://www.brewersfriend.com/homebrew/css/app_style.min.css?version=1561561010" rel="stylesheet" type="text/css"/>
#    <script src="https://www.brewersfriend.com/homebrew/js/jquery.1.12.4.min.js?ver=1561561010" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     window.jQuery || document.write('<script type="text/javascript" src="https://www.brewersfriend.com/homebrew/js/jquery.1.12.4.min.js?ver=1561561010_1561732532"><\/script>');
#    </script>
#    <script src="https://www.brewersfriend.com/homebrew/js/jquery-ui-1.12.1.custom.js?version=1561561010" type="text/javascript">
#    </script>
#    <script src="https://www.brewersfriend.com/homebrew/js/jquery.ui.touch-punch.min.js?version=1561561010" type="text/javascript">
#    </script>
#    <!-- <script src="http://code.jquery.com/jquery-migrate-1.4.1.js"></script> -->
#    <script src="https://cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js">
#    </script>
#    <script src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.22.2/moment.min.js">
#    </script>
#    <link href="https://fonts.googleapis.com/css?family=Lobster" rel="stylesheet" type="text/css"/>
#    <link href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" rel="stylesheet" type="text/css"/>
#    <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,400italic,600,700,700italic" rel="stylesheet" type="text/css"/>
#    <meta content="Browse homebrew beer recipes for all-grain, extract, and partial mash.  Sort by Style, Batch Size, ABV, etc." name="description"/>
#    <meta content="Homebrew Beer Recipes | Brewer's Friend" property="og:title"/>
#    <meta content="Browse homebrew beer recipes for all-grain, extract, and partial mash.  Sort by Style, Batch Size, ABV, etc." property="og:description"/>
#    <meta content="https://www.brewersfriend.com/homebrew/images/brewersfriend_ogimage_20180729.jpg" property="og:image"/>
#    <meta content="website" property="og:type"/>
#    <script src="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/transition.min.js">
#    </script>
#    <script src="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/dropdown.min.js">
#    </script>
#    <script src="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/dimmer.min.js">
#    </script>
#    <script src="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/modal.min.js">
#    </script>
#    <script src="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.4.1/components/search.min.js">
#    </script>
#    <link href="https://www.brewersfriend.com/apple-touch-icon.png" rel="apple-touch-icon"/>
#    <!-- iPhone(first generation or 2G), iPhone 3G, iPhone 3GS -->
#    <link href="https://www.brewersfriend.com/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#    <!-- iPad and iPad mini @1x -->
#    <link href="https://www.brewersfriend.com/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#    <!-- iPhone 4, iPhone 4s, iPhone 5, iPhone 5c, iPhone 5s, iPhone 6, iPhone 6s, iPhone 7, iPhone 7s, iPhone8 -->
#    <link href="https://www.brewersfriend.com/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#    <!-- iPad and iPad mini @2x -->
#    <link href="https://www.brewersfriend.com/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#    <!-- iPad Pro -->
#    <link href="https://www.brewersfriend.com/apple-touch-icon-167x167.png" rel="apple-touch-icon" sizes="167x167"/>
#    <!-- iPhone X, iPhone 8 Plus, iPhone 7 Plus, iPhone 6s Plus, iPhone 6 Plus -->
#    <link href="https://www.brewersfriend.com/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#    <!-- Android Devices High Resolution -->
#    <link href="https://www.brewersfriend.com/apple-touch-icon-192x192.png" rel="icon" sizes="192x192"/>
#    <!-- Android Devices Normal Resolution -->
#    <link href="https://www.brewersfriend.com/apple-touch-icon-128x128.png" rel="icon" sizes="128x128"/>
#    <meta content="width=device-width, initial-scale=1, minimum-scale=0.5, maximum-scale=1" name="viewport"/>
#    <script src="https://js.stripe.com/v3/" type="text/javascript">
#    </script>
#    <link href="https://www.brewersfriend.com/homebrew/css/jquery.fancybox.css?version=1561561010" media="screen" rel="stylesheet" type="text/css">
#     <script src="https://www.brewersfriend.com/homebrew/js/jquery.fancybox.pack.js?ver=1561561010" type="text/javascript">
#     </script>
#     <script type="text/javascript">
#      jQuery(document).ready(function(){
#     	$('.bf-hamburger').click(function(e){
#             if ($('body').hasClass('bf-navbar_expanded')) {
#                 $('body').removeClass('bf-navbar_expanded');
#             } else {
#                 $('body').addClass('bf-navbar_expanded');
#             }
#         });
#         $('#navbar>a').click(function(e){
#             e.stopPropagation();
#             if ($('body').hasClass('bf-navbar_expanded')) {
#                 $('body').removeClass('bf-navbar_expanded');
#             }
#         });
#     });
#     </script>
#    </link>
#   </meta>
#  </head>
#  <body>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KJGMPS" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script type="text/javascript">
#    function sendTopBannerEventToGa() {
# 		if (window.ga) {
# 			ga('create', 'UA-32415380-35', 'auto', 'topBannerTracker');
# 			ga('topBannerTracker.send', 'event', 'TopBar', 'View', "topbar_20181102_v2___bg_dg__an_fi__bt_su__bc_or__tx_10");
# 		} else {
# 			setTimeout(sendTopBannerEventToGa, 250);
# 		}
# 	}
# 	sendTopBannerEventToGa();
#   </script>
#   <style type="text/css">
#    #pre-header-banner {
#     background: #43a800;
#     color: white;
#     font-size: 17px;
#     padding: 5px 30px;
#     text-align: center;
#     box-shadow: 0 -10px 10px 10px rgba(0,0,0,0.5);
#     z-index: 10000;
#     position: relative;
#     min-height: 40px;
#     opacity: 0;
#     background: #222;
# }
#
# #pre-header-banner .insetbutton {
#     background: #f35b2d;
# }
#
# #pre-header-banner .closebutton {
#     position: absolute;
#     right: 10px;
#     color: white;
#     font-weight: bold;
#     font-size: 24px;
#     line-height: 24px;
#     display: block;
#     top: 50%;
#     margin-top: -12px;
# }
#   </style>
#   <div id="pre-header-banner">
#    <span>
#     Unlimited Recipes, No Ads, Premium Support.  Save 5% on Brewer's Friend Premium today.  Use code
#     <b>
#      5OFF
#     </b>
#     .
#    </span>
#    <a class="insetbutton" href="/homebrew/signup?utm_source=bf&amp;utm_medium=topbar&amp;utm_campaign=5off&amp;utm_content=topbar_20181102_v2___bg_dg__an_fi__bt_su__bc_or__tx_10" style="margin-left: 10px;">
#     Sign Up
#    </a>
#    <a class="closebutton" href="#">
#     ×
#    </a>
#   </div>
#   <script type="text/javascript">
#    jQuery(function($) {
#     $('#pre-header-banner .closebutton').click(function() {
#         $('#pre-header-banner').slideUp();
#
#         var days = 7;
#         var name = 'bf_phb_hidden_v3';
#         var value = 1;
#
# 	var date = new Date();
# 	date.setTime(date.getTime()+(days*24*60*60*1000));
# 	var expires = "; expires="+date.toGMTString();
#         document.cookie = name+"="+value+expires+"; path=/";
#     });
#
#         $('#pre-header-banner').fadeTo(1000,1);
#     });
#   </script>
#   <div id="header">
#    <a href="/">
#     <img alt="Brewer's Friend Beer Brewing Software" class="largebflogo" src="https://www.brewersfriend.com/homebrew/images/bglogo_large.png"/>
#    </a>
#    <div id="titlebar">
#     <div id="titletext">
#      <h1>
#       <img alt="Brewer's Friend Home Brewing Software" src="https://www.brewersfriend.com/homebrew/images/brewersfriendname_hires.png" style="max-width:275px;"/>
#       <div style="display: none;">
#        Brewer's Friend Home Brewing Software
#       </div>
#      </h1>
#      <p>
#       Brewing With Total Confidence
#      </p>
#     </div>
#     <div id="loginstatus">
#      <span class="loginmessage">
#       Welcome Guest!
#      </span>
#      <br/>
#      <a href="https://www.brewersfriend.com/homebrew/login/">
#       Login
#      </a>
#      |
#      <a href="https://www.brewersfriend.com/homebrew/signup/">
#       Sign Up
#      </a>
#     </div>
#     <div class="bf-hamburger">
#      <div class="hamburger-box">
#       <div class="hamburger-inner">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="titleaccent">
#    </div>
#    <div id="navbar">
#     <a name="top">
#     </a>
#     <ul class="menu">
#      <li class="dropdown">
#       <a href="#" onclick="return false;">
#        Community
#       </a>
#       <ul>
#        <li>
#         <a href="https://www.brewersfriend.com/blog/">
#          Blog
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/forum/">
#          Forum
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="dropdown">
#       <a href="#" onclick="return false;">
#        Tools
#       </a>
#       <ul>
#        <li>
#         <a href="https://www.brewersfriend.com/stats/">
#          Calculators
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/brewdaysheets/">
#          Brew Day Sheets
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/beer-charts/">
#          Charts
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/water-profiles/">
#          Water Profiles
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/windows/">
#          Windows App
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/recipe/import/">
#          Import Recipes
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="dropdown">
#       <a href="#" onclick="return false;">
#        Search
#       </a>
#       <ul>
#        <li>
#         <a href="https://www.brewersfriend.com/search/">
#          Beer Recipes
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/search/">
#          Site Wide Search
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/search-members/">
#          Search Members
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="dropdown">
#       <a href="#" onclick="return false;">
#        Browse
#       </a>
#       <ul>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew-recipes/">
#          Recipes
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/fermentables/">
#          Fermentables
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/hops/">
#          Hops
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/yeasts/">
#          Yeast
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/other/">
#          Other Ingredients
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/styles/">
#          Beer Styles
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/members/">
#          Members
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="dropdown">
#       <a href="#" onclick="return false;">
#        My Brewing
#       </a>
#       <ul>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/dashboard/">
#          My Dashboard
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/mybrewing/">
#          My Brew Sessions
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/myrecipes/">
#          My Recipes
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/myshopping/">
#          My Shopping List
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/myinventory/">
#          My Inventory
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/profile/equipment/">
#          My Equipment
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/mynotes/">
#          My Notes
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/mywatercalcs/">
#          My Water Calcs
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/brewingreport/">
#          My Brewing Report
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/homebrew/profile/">
#          My Profile
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="dropdown">
#       <a href="#" onclick="return false;">
#        Learn
#       </a>
#       <ul>
#        <li>
#         <a href="https://docs.brewersfriend.com/">
#          Documentation
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/faq">
#          FAQs
#         </a>
#        </li>
#        <li>
#         <a href="https://www.brewersfriend.com/feedback-welcome/">
#          Support
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="dropdown">
#       <a href="https://www.brewersfriend.com/homebrew/recipe/calculator" style="background:none;">
#        New Beer Recipe
#       </a>
#      </li>
#     </ul>
#     <div class="clear">
#     </div>
#    </div>
#    <script type="text/javascript">
#     jQuery(document).ready(function(){
#         $( "#navbar select" ).navSelect();
#         $( "#navbar>ul>li" ).click(function() {
#             $(this).siblings().not($(this)).removeClass('hover');
#             $(this).toggleClass('hover');
#         });
#         $( "#navbar>ul>li" ).hover(function() {
#                 $(this).siblings().not($(this)).removeClass('hover');
#             },
#             function() {
#             });
#     });
#    </script>
#    <div class="headbgcontainer">
#     <div class="headbg">
#     </div>
#    </div>
#   </div>
#   <div align="center" class="centerContent">
#    <div class="appcontent">
#     <style>
#      .batchcolor { float: right; margin-top: -7px; }
# .reviews { height: 16px; display: inline-block; margin-left:-15px; }
# .reviews label { color: #666666; float: left; font: bold 13px/27px Arial,Helvetica,sans-serif; width: 106px; }
# .reviews ul { float: left; margin-top: 0; padding-left: 0; width: 90px; }
# .reviews ul li { background: url("/images/yellow-star1.gif") no-repeat scroll 0 0 transparent; float: left; height: 16px; width: 16px; }
# .reviews ul li a { float: left; height: 16px; width: 16px; }
# .reviews ul li a.active { background: url("/images/yellow-star.gif") no-repeat scroll 0 0 transparent; }
# .reviews ul li a.last { background: url("/images/yellow-star.gif") no-repeat scroll 0 0 transparent; width: 50%; }
# .reviews ul li span { float: left; height: 16px; width: 16px; }
# .reviews ul li span.active { background: url("/images/yellow-star.gif") no-repeat scroll 0 0 transparent; }
# .reviews ul li span.last { background: url("/images/yellow-star.gif") no-repeat scroll 0 0 transparent; width: 50%; }
# .reviews span { float: left; color:black; font: 12px MuseoSans500,Helvetica,Arial,sans-serif; }
# ul { list-style: outside none none; }
# .paging { float: left; margin-top: 0px; padding: 5px 0; text-align: center; width: 100%; }
# .paging ul { float: right; margin-right: 10px; padding: 0; width: auto; }
# .paging ul li { float: left; padding: 0 7px 0 0; width: auto; }
# .paging ul li a { background: none repeat scroll 0 0 #eeeeee; border: 1px solid #cfcfcf; color: #5c5c5c; float: left; font: bold 12px/23px Arial,Helvetica,sans-serif; padding: 0 8px; width: auto; }
# .paging ul li a.active { background: none repeat scroll 0 0 #822e02; color: #fff; }
# .paging ul li a:hover { background: none repeat scroll 0 0 #822e02; color: #fff; }
# .recipeCategory { display:none; }
#     </style>
#     <script>
#      function expandex(recipeid)
#  {
#   if(document.getElementById('expand'+recipeid).style.display=='none') { document.getElementById('expand'+recipeid).style.display = 'table-row'; document.getElementById('dropimage'+recipeid).src = 'https://www.brewersfriend.com/images/minus.png'; }
#   else { document.getElementById('expand'+recipeid).style.display = 'none'; document.getElementById('dropimage'+recipeid).src = 'https://www.brewersfriend.com/images/plus.png'; }
#  }
#     </script>
#     <div class="ingredient-page-content">
#      <div class="breadcrumbs">
#       <div itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb" style="float:left;">
#        <a href="/" itemprop="url">
#         <span itemprop="title">
#          Home
#         </span>
#        </a>
#       </div>
#       <div style="float:left;">
#        »
#       </div>
#       <div itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb" style="float:left;">
#        <a href="https://www.brewersfriend.com/homebrew-recipes/" itemprop="url">
#         <span itemprop="title">
#          Browse Recipes
#         </span>
#        </a>
#       </div>
#       <div style="float:left;">
#        »
#       </div>
#       <div itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb" style="float:left;">
#        <a href="/homebrew-recipes/page/1/" itemprop="url">
#         <span itemprop="title">
#          Page 1
#         </span>
#        </a>
#       </div>
#      </div>
#      <div style="clear:both;">
#      </div>
#      <h1>
#       Browse Recipes
#      </h1>
#      <table cellpadding="10" cellspacing="0">
#       <tr>
#        <th>
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=titledown">
#           <b>
#            Title
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th>
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=styledown">
#           <b>
#            Style
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th width="60">
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=sizedown">
#           <b>
#            Size
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th width="50">
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=abvdown">
#           <b>
#            ABV
#            <img src="/images/sortasc.gif" style="float:right;"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th width="55">
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=ibudown">
#           <b>
#            IBU
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th width="45">
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=ogdown">
#           <b>
#            OG
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th width="45">
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=fgdown">
#           <b>
#            FG
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th width="105">
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=colordown">
#           <b>
#            Color
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th width="80">
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=methoddown">
#           <b>
#            Method
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th width="70">
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=viewsdown">
#           <b>
#            Views
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th width="80">
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=brewedup">
#           <b>
#            Brewed
#            <img src="/images/sortdesc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#        <th>
#         <font style="font-size:16px;font-weight:bold;">
#          <a href="?sort=ratingdown">
#           <b>
#            Rating
#            <img src="/images/sortasc.gif"/>
#           </b>
#          </a>
#         </font>
#        </th>
#       </tr>
#       <article>
#        <tr bgcolor="#fcfcfc">
#         <td width="300">
#          <a href="javascript:expandex(28546);">
#           <img id="dropimage28546" src="https://www.brewersfriend.com/images/plus.png" style="float:left;margin-top:5px;margin-right:3px;"/>
#          </a>
#          <div style="float:left;margin-top:4px;">
#           <a href="/homebrew/recipe/view/28546/sierra-nevada-pale-ale-clone">
#            <span itemprop="name">
#             Sierra Nevada Pale Ale ...
#            </span>
#           </a>
#          </div>
#         </td>
#         <td width="200">
#          <a href="/styles/american-pale-ale/">
#           <span itemprop="recipeCuisine">
#            American Pale Ale
#           </span>
#          </a>
#         </td>
#         <td>
#          <span itemprop="recipeYield">
#           6.5 Gal
#          </span>
#         </td>
#         <td>
#          5.58%
#         </td>
#         <td>
#          40.12
#         </td>
#         <td>
#          1.055
#         </td>
#         <td>
#          1.013
#         </td>
#         <td>
#          8°L
#          <div class="batchcolor">
#           <div class="color batchColor" style="background-color: #EA8F00;">
#           </div>
#           <div class="mug">
#           </div>
#          </div>
#         </td>
#         <td>
#          All Grain
#         </td>
#         <td>
#          193117
#         </td>
#         <div class="recipeCategory" itemprop="recipeCategory">
#          Beer
#         </div>
#         <td style="text-align:center;">
#          481
#         </td>
#         <td style="text-align:center;">
#          <div class="reviews">
#           <ul style="list-style: outside none none;">
#            <li style="text-decoration:none;">
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="last" style="width: 73%;">
#             </span>
#            </li>
#           </ul>
#          </div>
#         </td>
#        </tr>
#        <tr id="expand28546" style="display:none;overflow:hidden;">
#         <td colspan="12" style="border:1px solid #eeefff;">
#          <table bgcolor="#eeefff" border="0" cellspacing="1" height="100" style="margin:0px;border-radius: 2px;" width="100%">
#           <tr>
#            <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
#             <b>
#              Title:
#             </b>
#             Sierra Nevada Pale Ale Clone
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
#             <table cellpadding="0" cellspacing="0" style="margin:0px;width:1px;">
#              <tr>
#               <td align="left" valign="middle">
#                <b>
#                 Author:
#                </b>
#               </td>
#               <td style="white-space: nowrap;" valign="middle">
#                <a href="https://www.brewersfriend.com/homebrew/brewer/5889">
#                 <font style="font-weight:700;color:#777;font-size:13px;line-height:1;">
#                  Ozarks Mountain Brew
#                 </font>
#                </a>
#               </td>
#              </tr>
#             </table>
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Boil Size:
#             </b>
#             7.75  Gal
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Time:
#             </b>
#             70
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Gravity:
#             </b>
#             1.047
#            </td>
#            <td bgcolor="white">
#             <b>
#              Efficiency:
#             </b>
#             79
#            </td>
#            <td bgcolor="white">
#             <b>
#              Mash Thickness:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Sugar Scale:
#             </b>
#             Specific Gravity
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Brew Method:
#             </b>
#             All Grain
#            </td>
#            <td bgcolor="white">
#             <b>
#              Pitch Rate:
#             </b>
#             1.0
#            </td>
#            <td bgcolor="white">
#             <b>
#              Primary Temp:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Method:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Amount:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Creation Date:
#             </b>
#             12/27/2012 09:03 PM
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white" colspan="6">
#             <b>
#              Notes:
#             </b>
#             if your like me and love hops just add an ounce of Cascade to your keg, let it slow carbonate for a 3 or 4 days then take it out and enjoy a great beer!
#             <br/>
#             <br/>
#             Adjust your caramel 60L and shoot for an SRM of 8.
#            </td>
#           </tr>
#          </table>
#         </td>
#        </tr>
#       </article>
#       <article>
#        <tr bgcolor="#eeeeee">
#         <td width="300">
#          <a href="javascript:expandex(363082);">
#           <img id="dropimage363082" src="https://www.brewersfriend.com/images/plus.png" style="float:left;margin-top:5px;margin-right:3px;"/>
#          </a>
#          <div style="float:left;margin-top:4px;">
#           <a href="/homebrew/recipe/view/363082/avg-perfect-northeast-ipa-neipa-">
#            <span itemprop="name">
#             Avg. Perfect Northeast ...
#            </span>
#           </a>
#          </div>
#         </td>
#         <td width="200">
#          <a href="/styles/specialty-ipa-new-england-ipa/">
#           <span itemprop="recipeCuisine">
#            Specialty IPA: New England IPA
#           </span>
#          </a>
#         </td>
#         <td>
#          <span itemprop="recipeYield">
#           5.75 Gal
#          </span>
#         </td>
#         <td>
#          6.5%
#         </td>
#         <td>
#          50.6
#         </td>
#         <td>
#          1.062
#         </td>
#         <td>
#          1.013
#         </td>
#         <td>
#          5.2°L
#          <div class="batchcolor">
#           <div class="color batchColor" style="background-color: #FBB123;">
#           </div>
#           <div class="mug">
#           </div>
#          </div>
#         </td>
#         <td>
#          All Grain
#         </td>
#         <td>
#          196975
#         </td>
#         <div class="recipeCategory" itemprop="recipeCategory">
#          Beer
#         </div>
#         <td style="text-align:center;">
#          224
#         </td>
#         <td style="text-align:center;">
#          <div class="reviews">
#           <ul style="list-style: outside none none;">
#            <li style="text-decoration:none;">
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="last" style="width: 66%;">
#             </span>
#            </li>
#           </ul>
#          </div>
#         </td>
#        </tr>
#        <tr id="expand363082" style="display:none;overflow:hidden;">
#         <td colspan="12" style="border:1px solid #eeefff;">
#          <table bgcolor="#eeefff" border="0" cellspacing="1" height="100" style="margin:0px;border-radius: 2px;" width="100%">
#           <tr>
#            <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
#             <b>
#              Title:
#             </b>
#             Avg. Perfect Northeast IPA (NEIPA)
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
#             <table cellpadding="0" cellspacing="0" style="margin:0px;width:1px;">
#              <tr>
#               <td align="left" valign="middle">
#                <b>
#                 Author:
#                </b>
#               </td>
#               <td style="white-space: nowrap;" valign="middle">
#                <a href="https://www.brewersfriend.com/homebrew/brewer/49801">
#                 <font style="font-weight:700;color:#777;font-size:13px;line-height:1;">
#                  kcq101
#                 </font>
#                </a>
#               </td>
#              </tr>
#             </table>
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Boil Size:
#             </b>
#             7.5  Gal
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Time:
#             </b>
#             60
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Gravity:
#             </b>
#             1.048
#            </td>
#            <td bgcolor="white">
#             <b>
#              Efficiency:
#             </b>
#             70
#            </td>
#            <td bgcolor="white">
#             <b>
#              Mash Thickness:
#             </b>
#             1.25
#            </td>
#            <td bgcolor="white">
#             <b>
#              Sugar Scale:
#             </b>
#             Specific Gravity
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Brew Method:
#             </b>
#             All Grain
#            </td>
#            <td bgcolor="white">
#             <b>
#              Pitch Rate:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Primary Temp:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Method:
#             </b>
#             Keg - Force Carb.
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Amount:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Creation Date:
#             </b>
#             05/31/2016 02:52 PM
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white" colspan="6">
#             <b>
#              Notes:
#             </b>
#             Fermentation Dry Hop @ 70% attenuation (1.027)
#             <br/>
#             Traditional Dry Hop after fermentation is complete.
#             <br/>
#             <br/>
#             Fermentation temp: 68F
#            </td>
#           </tr>
#          </table>
#         </td>
#        </tr>
#       </article>
#       <article>
#        <tr bgcolor="#fcfcfc">
#         <td width="300">
#          <a href="javascript:expandex(5916);">
#           <img id="dropimage5916" src="https://www.brewersfriend.com/images/plus.png" style="float:left;margin-top:5px;margin-right:3px;"/>
#          </a>
#          <div style="float:left;margin-top:4px;">
#           <a href="/homebrew/recipe/view/5916/zombie-dust-clone-all-grain">
#            <span itemprop="name">
#             Zombie Dust Clone - ALL...
#            </span>
#           </a>
#          </div>
#         </td>
#         <td width="200">
#          <a href="/styles/american-ipa/">
#           <span itemprop="recipeCuisine">
#            American IPA
#           </span>
#          </a>
#         </td>
#         <td>
#          <span itemprop="recipeYield">
#           6 Gal
#          </span>
#         </td>
#         <td>
#          5.94%
#         </td>
#         <td>
#          54.57
#         </td>
#         <td>
#          1.061
#         </td>
#         <td>
#          1.016
#         </td>
#         <td>
#          8.5°L
#          <div class="batchcolor">
#           <div class="color batchColor" style="background-color: #E58500;">
#           </div>
#           <div class="mug">
#           </div>
#          </div>
#         </td>
#         <td>
#          All Grain
#         </td>
#         <td>
#          177751
#         </td>
#         <div class="recipeCategory" itemprop="recipeCategory">
#          Beer
#         </div>
#         <td style="text-align:center;">
#          169
#         </td>
#         <td style="text-align:center;">
#          <div class="reviews">
#           <ul style="list-style: outside none none;">
#            <li style="text-decoration:none;">
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="last" style="width: 57%;">
#             </span>
#            </li>
#           </ul>
#          </div>
#         </td>
#        </tr>
#        <tr id="expand5916" style="display:none;overflow:hidden;">
#         <td colspan="12" style="border:1px solid #eeefff;">
#          <table bgcolor="#eeefff" border="0" cellspacing="1" height="100" style="margin:0px;border-radius: 2px;" width="100%">
#           <tr>
#            <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
#             <b>
#              Title:
#             </b>
#             Zombie Dust Clone - ALL GRAIN
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
#             <table cellpadding="0" cellspacing="0" style="margin:0px;width:1px;">
#              <tr>
#               <td align="left" valign="middle">
#                <b>
#                 Author:
#                </b>
#               </td>
#               <td style="white-space: nowrap;" valign="middle">
#                <font style="font-weight:700;color:#777;font-size:13px;line-height:1;">
#                 Players Only Brewing
#                </font>
#               </td>
#              </tr>
#             </table>
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Boil Size:
#             </b>
#             7  Gal
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Time:
#             </b>
#             60
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Gravity:
#             </b>
#             1.053
#            </td>
#            <td bgcolor="white">
#             <b>
#              Efficiency:
#             </b>
#             70
#            </td>
#            <td bgcolor="white">
#             <b>
#              Mash Thickness:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Sugar Scale:
#             </b>
#             Specific Gravity
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Brew Method:
#             </b>
#             All Grain
#            </td>
#            <td bgcolor="white">
#             <b>
#              Pitch Rate:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Primary Temp:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Method:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Amount:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Creation Date:
#             </b>
#             03/29/2012 02:27 PM
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white" colspan="6">
#             <b>
#              Notes:
#             </b>
#             N/A
#            </td>
#           </tr>
#          </table>
#         </td>
#        </tr>
#       </article>
#       <article>
#        <tr bgcolor="#eeeeee">
#         <td width="300">
#          <a href="javascript:expandex(5920);">
#           <img id="dropimage5920" src="https://www.brewersfriend.com/images/plus.png" style="float:left;margin-top:5px;margin-right:3px;"/>
#          </a>
#          <div style="float:left;margin-top:4px;">
#           <a href="/homebrew/recipe/view/5920/zombie-dust-clone-extract">
#            <span itemprop="name">
#             Zombie Dust Clone - EXT...
#            </span>
#           </a>
#          </div>
#         </td>
#         <td width="200">
#          <a href="/styles/american-ipa/">
#           <span itemprop="recipeCuisine">
#            American IPA
#           </span>
#          </a>
#         </td>
#         <td>
#          <span itemprop="recipeYield">
#           5 Gal
#          </span>
#         </td>
#         <td>
#          6.16%
#         </td>
#         <td>
#          64.77
#         </td>
#         <td>
#          1.063
#         </td>
#         <td>
#          1.016
#         </td>
#         <td>
#          8.98°L
#          <div class="batchcolor">
#           <div class="color batchColor" style="background-color: #E58500;">
#           </div>
#           <div class="mug">
#           </div>
#          </div>
#         </td>
#         <td>
#          Extract
#         </td>
#         <td>
#          170352
#         </td>
#         <div class="recipeCategory" itemprop="recipeCategory">
#          Beer
#         </div>
#         <td style="text-align:center;">
#          145
#         </td>
#         <td style="text-align:center;">
#          <div class="reviews">
#           <ul style="list-style: outside none none;">
#            <li style="text-decoration:none;">
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="active">
#             </span>
#            </li>
#            <li>
#             <span class="last" style="width: 57%;">
#             </span>
#            </li>
#           </ul>
#          </div>
#         </td>
#        </tr>
#        <tr id="expand5920" style="display:none;overflow:hidden;">
#         <td colspan="12" style="border:1px solid #eeefff;">
#          <table bgcolor="#eeefff" border="0" cellspacing="1" height="100" style="margin:0px;border-radius: 2px;" width="100%">
#           <tr>
#            <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
#             <b>
#              Title:
#             </b>
#             Zombie Dust Clone - EXTRACT
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
#             <table cellpadding="0" cellspacing="0" style="margin:0px;width:1px;">
#              <tr>
#               <td align="left" valign="middle">
#                <b>
#                 Author:
#                </b>
#               </td>
#               <td style="white-space: nowrap;" valign="middle">
#                <font style="font-weight:700;color:#777;font-size:13px;line-height:1;">
#                 Players Only Brewing
#                </font>
#               </td>
#              </tr>
#             </table>
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Boil Size:
#             </b>
#             6  Gal
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Time:
#             </b>
#             60
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Gravity:
#             </b>
#             1.052
#            </td>
#            <td bgcolor="white">
#             <b>
#              Efficiency:
#             </b>
#             70
#            </td>
#            <td bgcolor="white">
#             <b>
#              Mash Thickness:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Sugar Scale:
#             </b>
#             Specific Gravity
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Brew Method:
#             </b>
#             Extract
#            </td>
#            <td bgcolor="white">
#             <b>
#              Pitch Rate:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Primary Temp:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Method:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Amount:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Creation Date:
#             </b>
#             03/29/2012 02:52 PM
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white" colspan="6">
#             <b>
#              Notes:
#             </b>
#             Steep the grains in the mid 150s for 45-60 minutes.
#             <br/>
#             It is assuming a 5 gallon batch,
#             <br/>
#             3 gallon - 60 minute boil, and adding the extract at the beginning.
#             <br/>
#             <br/>
#             If you can do a full boil you probably wouldn't need the extra 1oz.Citra at 60 minutes.
#             <br/>
#             <br/>
#             Extract notes from the forum thread author:
#             <br/>
#             As far as First Wort Hop / Steeping hops.... I would add them with around 10 min left in steep (before rinse), and put them in a different bag than the grain. Then you can leave them in for the whole boil.
#             <br/>
#             <br/>
#             Original Authors Beer Profile:
#             <br/>
#             Estimated Original Gravity: 1.066 SG
#             <br/>
#             Estimated Final Gravity: 1.018 SG
#             <br/>
#             Estimated Color: 9.0 SRM
#             <br/>
#             Bitterness: 65.2 IBU
#             <br/>
#             <br/>
#            </td>
#           </tr>
#          </table>
#         </td>
#        </tr>
#       </article>
#       <article>
#        <tr bgcolor="#fcfcfc">
#         <td width="300">
# ...
#                 Author:
#                </b>
#               </td>
#               <td style="white-space: nowrap;" valign="middle">
#                <a href="https://www.brewersfriend.com/homebrew/brewer/16332">
#                 <font style="font-weight:700;color:#777;font-size:13px;line-height:1;">
#                  mystikhybrid
#                 </font>
#                </a>
#               </td>
#              </tr>
#             </table>
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Boil Size:
#             </b>
#             7.5  Gal
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Time:
#             </b>
#             60
#            </td>
#            <td bgcolor="white">
#             <b>
#              Boil Gravity:
#             </b>
#             1.057
#            </td>
#            <td bgcolor="white">
#             <b>
#              Efficiency:
#             </b>
#             80
#            </td>
#            <td bgcolor="white">
#             <b>
#              Mash Thickness:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Sugar Scale:
#             </b>
#             Specific Gravity
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white">
#             <b>
#              Brew Method:
#             </b>
#             BIAB
#            </td>
#            <td bgcolor="white">
#             <b>
#              Pitch Rate:
#             </b>
#             0.5
#            </td>
#            <td bgcolor="white">
#             <b>
#              Primary Temp:
#             </b>
#             65 ° F
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Method:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Priming Amount:
#             </b>
#             N/A
#            </td>
#            <td bgcolor="white">
#             <b>
#              Creation Date:
#             </b>
#             08/31/2016 09:00 PM
#            </td>
#           </tr>
#           <tr>
#            <td bgcolor="white" colspan="6">
#             <b>
#              Notes:
#             </b>
#             Update 2:
#             <br/>
#             Dry hop schedule is first addition at 36-48 hours into fermentation (to scrub O2 and oil biotransformation) , next dirrctly in keg for aroma.
#             <br/>
#             <br/>
#             Update 1:
#             <br/>
#             changed bemla+blueberyy to citra+apricot/peach
#             <br/>
#             Changed to poland spring water, reduced gypsum from 3 to 1.5
#             <br/>
#             Changed yeast to london III
#             <br/>
#             <br/>
#             You want a high CaCl for this style. My water goes like this, and should be a safe bet if you havent tested your water:
#             <br/>
#             3g CaCl
#             <br/>
#             3g Gypsum
#             <br/>
#             0.5 g Epsom Salts
#             <br/>
#             <br/>
#             If the pH is too high, this usually means adding acid malt (~1% of the grist for every intended .1 drop)
#             <br/>
#             If the pH is too low I add chalk (which should ideally be dissolved in carbonated water first) or baking soda (which can be added directly to the mash).
#             <br/>
#             <br/>
#             https://www.reddit.com/r/Homebrewing/comments/4wbz2g/th_milkshake_inspired_beer_sort_of/
#             <br/>
#             <br/>
#             http://threegodsbrewing.com/2016/05/02/musings-on-ne-style-ipas/
#             <br/>
#             <br/>
#             http://www.themadfermentationist.com/2015/06/hop-juice-north-east-ipa-recipe.html
#            </td>
#           </tr>
#          </table>
#         </td>
#        </tr>
#       </article>
#       <tr>
#        <td colspan="12">
#         <div class="paging">
#          <ul>
#           <li>
#            <a class="active" href="/homebrew-recipes/?sort=breweddown">
#             1
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/2/?sort=breweddown">
#             2
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/3/?sort=breweddown">
#             3
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/4/?sort=breweddown">
#             4
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/5/?sort=breweddown">
#             5
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/6/?sort=breweddown">
#             6
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/7/?sort=breweddown">
#             7
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/8/?sort=breweddown">
#             8
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/9/?sort=breweddown">
#             9
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/10/?sort=breweddown">
#             10
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/11/?sort=breweddown">
#             11
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/12/?sort=breweddown">
#             12
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/13/?sort=breweddown">
#             13
#            </a>
#           </li>
#           <li>
#            <a href="/homebrew-recipes/page/2/?sort=breweddown">
#             Next
#            </a>
#           </li>
#          </ul>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div id="footerpush">
#    </div>
#    <div id="footerbox">
#     <div id="footermenu">
#      <div id="footernamesoc">
#       <a href="https://www.brewersfriend.com/" id="footername">
#        <img alt="https://www.brewersfriend.com/" src="https://www.brewersfriend.com/homebrew/images/brewersfriendname72x171.png"/>
#       </a>
#       <div id="footersoc">
#        <a href="http://www.facebook.com/BrewersFriendSite" target="_blank">
#         <i class="fab fa-facebook">
#         </i>
#        </a>
#        <a href="http://www.twitter.com/brewers_friend" target="_blank">
#         <i class="fab fa-twitter">
#         </i>
#        </a>
#        <a href="https://www.instagram.com/brewersfriend/" target="_blank">
#         <i class="fab fa-instagram">
#         </i>
#        </a>
#       </div>
#      </div>
#      <ul>
#       <li id="footerPages">
#        Pages
#        <ul>
#         <li>
#          <a href="https://www.brewersfriend.com/">
#           Home
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/blog/">
#           Blog
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/forum/">
#           Forum
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/faq">
#           FAQ
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li id="footerTools">
#        Tools
#        <ul>
#         <li>
#          <a href="https://www.brewersfriend.com/homebrew/recipe/calculator">
#           Recipe Builder
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/brewdaysheets/">
#           Brew Day Sheets
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/stats/">
#           Brewing Calculators
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/homebrew/dashboard/">
#           My Dashboard
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li id="footerMore">
#        Search
#        <ul>
#         <li>
#          <a href="https://www.brewersfriend.com/homebrew/search/">
#           Site Search
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/search/">
#           Beer Recipes
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li id="footerLatest">
#        More
#        <ul>
#         <li>
#          <a href="https://www.brewersfriend.com/feedback-welcome/">
#           Contact
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/about/">
#           About
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/pricing/">
#           Pricing / Features
#          </a>
#         </li>
#         <li>
#          <a href="https://brewersfriend.postaffiliatepro.com/affiliates/" target="_blank">
#           Partner Program
#          </a>
#         </li>
#         <li>
#          <a href="https://www.brewersfriend.com/advertise/">
#           Advertise
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li id="footerSponsor-off">
#       </li>
#      </ul>
#     </div>
#     <div class="footer">
#      Copyright © 2007-2019 BrewersFriend.com -
#      <a href="https://www.brewersfriend.com/feedback-welcome/">
#       Send Feedback
#      </a>
#      -
#      <a href="https://www.brewersfriend.com/terms">
#       Terms
#      </a>
#      -
#      <a href="https://www.brewersfriend.com/feed/rss/">
#       RSS Feed
#      </a>
#     </div>
#    </div>
#    <script type="text/javascript">
#     $(document).ready(function() {
#
# 	if(navigator && navigator.userAgent.match(/iPhone/i) &&
# 		!getCookie('closeiphone')) {
# 		$('#iphoneBar').show();
# 	}
#
# 	$(".browse-search input").on("keyup", function() {
# 		var value = $(this).val().toLowerCase();
# 		$(".browse-results tbody tr").filter(function() {
# 			$(this).toggle($(this).text().toLowerCase().indexOf(value) > -1)
# 		});
# 		// update css
# 		$(".browse-results tbody tr:visible:even").css('background', '#eeeeee');
# 		$(".browse-results tbody tr:visible:odd").css('background', '#fff');
# 	});
# });
#    </script>
#    <script type="text/javascript">
#     window.bi_recipeJson = "";
# window.bi_recipeToken = "";
# /**
# * Gets recipe JSON from current form content
# */
# function buyRecipePostToHbs() {
#     var bi_form = $(
#             '<form action="https://www.homebrewsupply.com/homebrew-recipe-builder/save/bfBuy" method="POST">' +
#             '<input type="hidden" name="recipetoken" value="' + window.bi_recipeToken + '" />' +
#             '<input type="hidden" name="bi_form_data" id="bi_form_data_' + window.buyingredients_post_index + '" value="" />' +
#             '</form>'
#             ).appendTo('body');
#     $('#bi_form_data_' + window.buyingredients_post_index).val(window.bi_recipeJson);
#     bi_form.submit();
# }
#
# window.buyingredients_post_index = 0;
# $(document).ready(function() {
#     $(".buy-recipe-now-button").click(function(e) {
#         window.buyingredients_post_index++;
#
#         //get json for recipe if we're on the edit page
#         var recipeFormData = $("#calc").serialize();
#         if (recipeFormData != "") {
#             //first save the recipe
#             doPost(function(response) {
#
#                 var recipeId = response.recipeId;
#
#                 var ajaxRequest = $.ajax({
#                     url: "/homebrew/recipe/json/" + recipeId,
#                     type: "GET",
#                     timeout: 20000,
#                     success:function(data){
#                         var json = data;
#                         var parsed = $.parseJSON(data);
#                         window.buyingredients_post_index++;
#                         window.bi_recipeToken = parsed.recipetoken;
#                         window.bi_recipeJson = json;
#
#                         //re-enable everything
#                         enableButtonsAfterSave();
#                         setTimeout( function(){
#                             saveButtonActive(true,{});
#                         }, 500);
#
#                         //saveButtonActive(true,{});
#                         buyRecipePostToHbs();
#                     },
#                     error:function(request, status, error){
#                         showPostError(request.responseText);
#                         notification("There was an error saving your recipe, please make sure you are connected to the internet and try again.", {color : 'red'} );
#                     }
#                 });
#
#             });
#         }
#         else if (window.bi_recipeJson != "") {
#             buyRecipePostToHbs();
#         }
#         else {
#             //TODO: this shouldn't happen
#         }
#
#         return false;
#     });
# });
#    </script>
#    <div id="bf_exitpopup" style="display: none;">
#     <div id="bf_exitpopup_container" style="position: relative;">
#      <a href="https://www.brewersfriend.com/homebrew/signup/?utm_source=popup&amp;utm_campaign=exit_popup_20180118">
#       <img src="/homebrew/images/BF-EXIT-BANNER-2.png" style="display:block;max-width:100%;">
#       </img>
#      </a>
#      <a href="#" onclick="$('.fancybox-close').click();return false;" style="position: absolute; bottom: 0; width: 13%; height: 10%; left: 57%; margin-left: -5%;">
#      </a>
#     </div>
#    </div>
#    <script type="text/javascript">
#     window.b_bfShowExitPopup = function() {
# 	jQuery(function($) {
# 	if ( ! $.fancybox ) return;
#
# 	if (window.b_bfExitpopupShown) return;
# 	window.b_bfExitpopupShown = true;
# 	$.fancybox({
# 			//'width': '500px',
# 			//'height': '450px',
# 			'padding': '0px',
# 			'autoScale': true,
# 			'transitionIn': 'fade',
# 			'transitionOut': 'fade',
# 			'showCloseButton': true,
# 			'type': 'inline',
# 			'href': '#bf_exitpopup',
# 			'id': 'bf_exitpopup__fancybox'
# 			});
#
# 	//set cookie so we don't show it again
#
# 	var days = 7;
# 	var name = 'bf_exitpopup_shown_v3';
# 	var value = 1;
#
# 	if (days) {
# 		var date = new Date();
# 		date.setTime(date.getTime()+(days*24*60*60*1000));
# 		var expires = "; expires="+date.toGMTString();
# 	}
# 	else var expires = "";
# 	document.cookie = name+"="+value+expires+"; path=/";
# 	});
# };
#
# window.b_bfExitpopupShown = false;
#
# setTimeout(function() {
#     jQuery(function($) {
#         $(document).mouseleave(function() {
# 		window.b_bfShowExitPopup();
#         });
#     });
# }, 5000);
#
# setTimeout(function() {
#     jQuery(function($) {
# 	    window.b_bfShowExitPopup();
#     });
# }, 30000);
#    </script>
#    <script id="pap_x2s6df8d" src="https://brewersfriend.postaffiliatepro.com/scripts/hfelo4kj" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     try {
# PostAffTracker.setAccountId('default1');
# PostAffTracker.track();
# } catch (err) { }
#    </script>
#    <script type="text/javascript">
#     try {
# 	var links = document.getElementsByTagName('a');
#
# 	for (var i = 0, max = links.length; i < max; i++) {
#             // Amazon
# 	    var _href = links[i].href;
# 	    if (_href.indexOf('amazon.com') !== -1) {
# 		if (_href.indexOf('?') !== -1) {
# 		    _href += '&';
# 		}
# 		else {
# 		    _href += '?';
# 		}
# 		links[i].href = _href + 'tag=brewersfriend-20';
# 	    }
#
#             // HBS
# 	    var _href = links[i].href;
# 	    if (_href.indexOf('homebrewsupply.com') !== -1) {
# 		links[i].href = _href + '#a_aid=brewersfriend';
# 	    }
# 	}
# } catch (err) { }
#    </script>
#    <!-- Google Code for Remarketing Tag -->
#    <!--------------------------------------------------
# Remarketing tags may not be associated with personally identifiable information or placed on pages
# related to sensitive categories. See more information and instructions on how to setup the tag on:
# http://google.com/ads/remarketingsetup
# --------------------------------------------------->
#    <script type="text/javascript">
#     var google_tag_params = {
# 		//ecomm_prodid: 'REPLACE_WITH_VALUE',
# 		ecomm_pagetype: 'culture_brewersfriend' //,
# 		//ecomm_totalvalue: 'REPLACE_WITH_VALUE',
# 	};
#    </script>
#    <script type="text/javascript">
#     /* <![CDATA[ */
# 		var google_conversion_id = 954845969;
# 		var google_custom_params = window.google_tag_params;
# 		var google_remarketing_only = true;
# 	/* ]]> */
#    </script>
#    <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#    </script>
#    <noscript>
#     <div style="display:inline;">
#      <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/954845969/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1">
#      </img>
#     </div>
#    </noscript>
#   </div>
#  </body>
# </html>

# %%
header = [
    'title',
    'style',
    'size',
    'ABV',
    'IBU',
    'OG',
    'FG',
    'color',
    'method',
    'views',
    'brewed',
    'rating'
]

additional_info = [
    'size_unit',
    'author',
    'author_name',
    'boil_size',
    'boil_time',
    'boil_grav',
    'pitch_rate',
    'temp_prim',
    'temp_unit',
    'prim_method',
    'prim_amount',
    'prim_amount_unit',
    'creation_date'
]

url_columns = [
    'url_beer',
    'url_style',
    'url_author',
    'efficiency',
    'mash_thick',
    'sugar_scale'
]
columns = header + additional_info + url_columns

# %%
beer_df = pd.DataFrame(columns = columns)
idx = 0

page_num = 1
beers_collected = 0
while page_num <= 325:
    
    r = requests.get(url_home + '/homebrew-recipes/page/' + str(page_num) + '/?sort=breweddown', headers={'User-Agent': 'Mozilla/5.0'})
    soup = BeautifulSoup(r.text, 'html.parser')
    beers_table = soup.find('table')

    for row in beers_table.find_all('tr'):

        if (row.get('id') == None) & ((row.get('bgcolor') == '#fcfcfc') | (row.get('bgcolor') == '#eeeeee')):

            beer = pd.DataFrame(index=[idx], columns=columns)
            for i,cell in enumerate(row.find_all('td')):

                feature = header[i]
                beer[feature] = cell.text              

                if feature == 'title':
                    #get url
                    beer['url_beer'] = url_home + cell.find_all('a', href=True)[1]['href']

                elif feature == 'style':
                    #get url
                    beer['url_style'] = url_home + cell.find_all('a', href=True)[0]['href'] 

                elif feature == 'size':
                    txt = cell.text
                    beer['size'] = re.search(r'[0-9](\.[0-9]+)?', txt)[0]
                    beer['size_unit'] = re.search(r'[A-z]+', txt)[0]

                elif feature == 'ABV':
                    beer['ABV'] = re.sub(r'%', '', cell.text)

                elif feature == 'rating':
                    #rating integer part
                    beer['rating'] = len(cell.find_all('span', {'class':'active'})) 
                    #rating fractional part
                    if beer['rating'].values[0] != 5:
                        beer['rating'] += int(re.search(r'[0-9]+', cell.find('span', {'class':'last'})['style'])[0]) / 100

                elif feature == 'color':
                    beer['color'] = re.search(r'[0-9]+', cell.text)[0]

        elif (row.get('id') != None):
            if re.search(r'expand*', row.get('id')):

                info_table = row.find_all('table')[0]

                for i,tr in enumerate(info_table.findChildren('tr', recursive=False)):

                    #Title
                    if i == 0:
                        beer['title'] = tr.findChild('td').text.replace('Title:', '').strip()

                    #Author
                    elif i == 1:
                        if len(tr.find_all('font')) > 0:
                            beer['author_name'] = tr.find_all('font')[0].text
                            url = tr.find_all('a', href=True)
                            if len(url) > 0:
                                beer['url_author'] = url[0]['href']
                                if re.search(r'(?<=brewer\/)[0-9]+', url[0]['href']):
                                    beer['author'] = re.search(r'(?<=brewer\/)[0-9]+', url[0]['href'])[0]
                                else:
                                    beer['author'] = None
                            else: 
                                beer['url_author']  = None 
                                beer['author']      = None
                        else:
                            beer['author_name'] = None
                            beer['url_author']  = None 
                            beer['author']      = None

                   #Info row 1 
                    elif i == 2:
                        all_info_text = tr.text

                        tmp = re.search(r'(?<=Boil Size: )[0-9]+(\.[0-9]+)?', all_info_text)
                        if tmp != None:
                            beer['boil_size'] = tmp[0]
                        else:
                            beer['boil_size'] = None

                        tmp = re.search(r'(?<=Boil Time: )[0-9]+', all_info_text)
                        if tmp != None:
                            beer['boil_time'] = tmp[0]
                        else:
                            beer['boil_time'] = None

                        tmp = re.search(r'(?<=Boil Gravity: )[0-9]+(\.[0-9]+)?', all_info_text)
                        if tmp != None:
                            beer['boil_grav'] = tmp[0]
                        else:
                            beer['boil_grav'] = None

                        tmp = re.search(r'(?<=Efficiency: )[0-9]+', all_info_text)
                        if tmp != None:
                            beer['efficiency'] = tmp[0]
                        else:
                            beer['efficiency'] = None

                        tmp = re.search(r'(?<=Mash Thickness: )[0-9]+(\.[0-9]+)?', all_info_text)
                        if tmp != None:
                            beer['mash_thick'] = tmp[0]
                        else:
                            beer['mash_thick'] = None

                        tmp = re.search(r'(?<=Sugar Scale: )[A-z ]+', all_info_text)
                        if tmp != None:
                            beer['sugar_scale'] = tmp[0]
                        else:
                            beer['sugar_scale'] = None

                    #Info row 2
                    elif i == 3:
                        all_info_text = tr.text

                        tmp = re.search(r'(?<=Pitch Rate: )[0-9]+(\.[0-9]+)?', all_info_text)
                        if tmp != None:
                            beer['pitch_rate'] = tmp[0]
                        else:
                            beer['pitch_rate'] = None

                        tmp = re.search(r'(?<=Primary Temp: )[A-z0-9°\/\. ]+', all_info_text)
                        if (tmp[0].strip() != 'N/A') & (tmp != None):
                            beer['temp_prim'] = tmp[0].split('°')[0]
                            beer['temp_unit'] = tmp[0].split('°')[1]
                        else:
                            beer['temp_prim'] = None
                            beer['temp_unit'] = None

                        tmp = re.search(r'(?<=Priming Method: )[A-z\/\. ]+', all_info_text)
                        if (tmp != None):
                            if (tmp[0].strip() != 'N/A'):
                                beer['prim_method'] = tmp[0]
                            else:
                                beer['prim_method'] = None
                        else:
                            beer['prim_method'] = None

                        tmp = re.search(r'(?<=Priming Amount: )[A-z0-9\.\,\/\~ ]+', all_info_text)
                        if (tmp != None):
                            if (tmp[0].strip() != 'N/A'):
                                beer['prim_amount'] = tmp[0].split(' ')[0]
                                if len(tmp[0].split(' ')) > 1:
                                    beer['prim_amount_unit'] = tmp[0].split(' ')[1]
                                else:
                                    beer['prim_amount_unit'] = None
                            else:
                                beer['prim_amount'] = None
                                beer['prim_amount_unit'] = None
                        else:
                            beer['prim_amount'] = None
                            beer['prim_amount_unit'] = None

                        tmp = re.search(r'(?<=Creation Date: )[A-z0-9\/: ]+', all_info_text)
                        if tmp != None:
                            beer['creation_date'] = tmp[0]
                        else:
                            beer['creation_date'] = None


                beer_df = beer_df.append(beer,  verify_integrity=True, sort=False)
                beers_collected += 1
                idx += 1
                
    beer_df.to_csv('./data/beer_basic_data.csv')
    page_num += 1
    print('Scraping page:', page_num, '\t Beers collected:', beers_collected)
    beers_collected = 0

beer_df
# Out:
# Scraping page: 2 	 Beers collected: 20
# Scraping page: 3 	 Beers collected: 20
# Scraping page: 4 	 Beers collected: 20
# Scraping page: 5 	 Beers collected: 20
# Scraping page: 295 	 Beers collected: 20
# Scraping page: 296 	 Beers collected: 20
# Scraping page: 297 	 Beers collected: 20
# Scraping page: 298 	 Beers collected: 20
# Scraping page: 299 	 Beers collected: 20
# Scraping page: 300 	 Beers collected: 20
# Scraping page: 301 	 Beers collected: 20
# Scraping page: 302 	 Beers collected: 20
# Scraping page: 303 	 Beers collected: 20
# Scraping page: 304 	 Beers collected: 20
# Scraping page: 305 	 Beers collected: 20
# Scraping page: 306 	 Beers collected: 20
# Scraping page: 307 	 Beers collected: 20
# Scraping page: 308 	 Beers collected: 20
# Scraping page: 309 	 Beers collected: 20
# Scraping page: 310 	 Beers collected: 20
# Scraping page: 311 	 Beers collected: 20
# Scraping page: 312 	 Beers collected: 20
# Scraping page: 313 	 Beers collected: 20
# Scraping page: 314 	 Beers collected: 20
# Scraping page: 315 	 Beers collected: 20
# Scraping page: 316 	 Beers collected: 20
# Scraping page: 317 	 Beers collected: 20
# Scraping page: 318 	 Beers collected: 20
# Scraping page: 319 	 Beers collected: 20
# Scraping page: 320 	 Beers collected: 20
# Scraping page: 321 	 Beers collected: 20
# Scraping page: 322 	 Beers collected: 20
# Scraping page: 323 	 Beers collected: 20
# Scraping page: 324 	 Beers collected: 20
# Scraping page: 325 	 Beers collected: 20
# Scraping page: 326 	 Beers collected: 20
#                                                   title  \
# 0                          Sierra Nevada Pale Ale Clone
# 1                    Avg. Perfect Northeast IPA (NEIPA)
# 2                         Zombie Dust Clone - ALL GRAIN
# 3                           Zombie Dust Clone - EXTRACT
# 4                         Simple Citra IPA - One Gallon
# 5                                     Vanilla Cream Ale
# 6                           Southern Tier Pumking clone
# 7                       Great Lakes Christmas Ale Clone
# 8                               Bells two hearted clone
# 9                                Goose Island IPA Clone
# 10                        Siddhartha of Suburbia Saison
# 11                                   Mango Habanero IPA
# 12             Russian River Pliny the Elder (original)
# 13                             Hopped and Loaded 16 BBL
# 14                      Biermuncher's Centennial Blonde
# 15                             Chocolate Vanilla Porter
# 16    Julius | Tree House Brewing (approximation) Br...
# 17                                     Cascade Pale Ale
# 18                                  Syntax Error IPA II
# 19                          IPA - Tired Hands Milkshake
# 20              NEIPA Hoppy ( juicy) -  Braumeister 20L
# 21         Spotted Clown (New Glarus Spotted Cow clone)
# 22                                      Roche Four LODO
# 23                               Brewdog Punk IPA clone
# 24                                      Easy Blonde Ale
# 25                      Ballast Point Sculpin Ale Clone
# 26                                          Citra SMaSH
# 27                              Blue Moon Belgian White
# 28                       Bakke Brygg Belgisk Blond 50 L
# 29                            Bakke Brygg HveteIPA 25 L
# ...                                                 ...
# 6470                                 Palmer's Elevenses
# 6471                                      Imperial Pils
# 6472                                         Scotch Ale
# 6473                                          IPA - Red
# 6474                                       Ace of Hefes
# 6475                                            Pilsner
# 6476                     Apple Cyser with Cherries Mead
# 6477         Tupelo Honey Sparkling Show Mead (Saffron)
# 6478                 West Coast Amber (Chinook/Cascade)
# 6479                                Clone - Black Butte
# 6480                                  Jeanie's Favorite
# 13               Plato
# 14    Specific Gravity
# 15    Specific Gravity
# 16    Specific Gravity
# 17    Specific Gravity
# 18    Specific Gravity
# 19    Specific Gravity
# 20    Specific Gravity
# 21    Specific Gravity
# 22    Specific Gravity
# 23               Plato
# 24    Specific Gravity
# 25    Specific Gravity
# 26    Specific Gravity
# 27    Specific Gravity
# 28    Specific Gravity
# 29    Specific Gravity
# ...                ...
# 6470  Specific Gravity
# 6471  Specific Gravity
# 6472  Specific Gravity
# 6473  Specific Gravity
# 6474  Specific Gravity
# 6475  Specific Gravity
# 6476  Specific Gravity
# 6477  Specific Gravity
# 6478  Specific Gravity
# 6479  Specific Gravity
# 6480  Specific Gravity
# 6481  Specific Gravity
# 6482  Specific Gravity
# 6483  Specific Gravity
# 6484  Specific Gravity
# 6485  Specific Gravity
# 6486  Specific Gravity
# 6487  Specific Gravity
# 6488  Specific Gravity
# 6489  Specific Gravity
# 6490  Specific Gravity
# 6491  Specific Gravity
# 6492  Specific Gravity
# 6493  Specific Gravity
# 6494  Specific Gravity
# 6495  Specific Gravity
# 6496  Specific Gravity
# 6497  Specific Gravity
# 6498  Specific Gravity
# 6499  Specific Gravity
#
# [6500 rows x 31 columns]

# %%
tmp

# %%
row
# Out:
# <tr id="expand382205" style="display:none;overflow:hidden;"><td colspan="12" style="border:1px solid #eeefff;"> <table bgcolor="#eeefff" border="0" cellspacing="1" height="100" style="margin:0px;border-radius: 2px;" width="100%">
# <tr>
# <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
# <b>Title:</b> Munchen Grosses Bier - Jamil	  </td>
# </tr>
# <tr>
# <td bgcolor="white" colspan="6" style="vertical-align: top;" valign="top">
# <table cellpadding="0" cellspacing="0" style="margin:0px;width:1px;">
# <tr>
# <td align="left" valign="middle">
# <b>Author:</b>
# </td>
# <td style="white-space: nowrap;" valign="middle">
# <a href="https://www.brewersfriend.com/homebrew/brewer/45056"><font style="font-weight:700;color:#777;font-size:13px;line-height:1;">TZ</font></a> </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td bgcolor="white"><b>Boil Size:</b> 31.2  L</td>
# <td bgcolor="white"><b>Boil Time:</b> 90</td>
# <td bgcolor="white"><b>Boil Gravity:</b> 1.04</td>
# <td bgcolor="white"><b>Efficiency:</b> 65</td>
# <td bgcolor="white"><b>Mash Thickness:</b> N/A</td>
# <td bgcolor="white"><b>Sugar Scale:</b> Specific Gravity</td>
# </tr>
# <tr>
# <td bgcolor="white"><b>Brew Method:</b> BIAB</td>
# <td bgcolor="white"><b>Pitch Rate:</b> 1.75</td>
# <td bgcolor="white"><b>Primary Temp:</b> 10 ° C</td>
# <td bgcolor="white"><b>Priming Method:</b> bulk</td>
# <td bgcolor="white"><b>Priming Amount:</b> ?</td>
# <td bgcolor="white"><b>Creation Date:</b> 07/30/2016 07:35 AM</td>
# </tr>
# <tr>
# <td bgcolor="white" colspan="6"><b>Notes:</b> N/A</td>
# </tr>
# </table>
# </td></tr>

# %%
title = header[0]
print(title)
title == 'Title '
# Out:
# Title
# False

# %%
tmp = 'asd'
tmp == 'asd'
# Out:
# True
